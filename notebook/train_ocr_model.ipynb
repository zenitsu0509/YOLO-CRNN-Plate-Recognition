# %%
# !pip install easyocr torch torchvision opencv-python pillow datasets huggingface_hub albumentations -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 42.8 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 18.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 978.2/978.2 kB 51.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.6/300.6 kB 27.0 MB/s eta 0:00:00

# %%
import os
import random
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
from datasets import load_dataset
from tqdm.notebook import tqdm

# %%
# Load the processed Indian number plate dataset from Hugging Face
HF_DATASET_ID = "zenitsu09/indian-number-plate"

print(f"Loading dataset from: {HF_DATASET_ID}")
dataset = load_dataset(HF_DATASET_ID, split="train")

print(f"✓ Dataset loaded with {len(dataset)} samples")
print(f"Features: {dataset.features}")

# Preview a few samples
print("\nSample data:")
for i in range(min(3, len(dataset))):
    print(f"  [{i}] plate_text: {dataset[i]['plate_text']}")
# Out:
# Loading dataset from: zenitsu09/indian-number-plate
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# README.md:   0%|          | 0.00/564 [00:00<?, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/5.92M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1709 [00:00<?, ? examples/s]
# ✓ Dataset loaded with 1709 samples
# ...

# %%
# Split dataset into train/val (90/10)
dataset = dataset.shuffle(seed=42)
split = dataset.train_test_split(test_size=0.1, seed=42)
train_dataset_hf = split["train"]
val_dataset_hf = split["test"]

print(f"Total samples: {len(dataset)}")
print(f"Training samples: {len(train_dataset_hf)}")
print(f"Validation samples: {len(val_dataset_hf)}")

# Visualize a few training samples
fig, axes = plt.subplots(2, 4, figsize=(16, 6))
for i, ax in enumerate(axes.flat):
    if i < len(train_dataset_hf):
        sample = train_dataset_hf[i]
        img = sample["image"]
        label = sample["plate_text"]
        ax.imshow(img)
        ax.set_title(f"{label}", fontsize=10)
        ax.axis("off")
plt.suptitle("Training Samples", fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# Total samples: 1709
# Training samples: 1538
# Validation samples: 171

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import albumentations as A
from albumentations.pytorch import ToTensorV2
import sys

# Configuration - OPTIMIZED for better accuracy
CONFIG = {
    'batch_size': 16,  # Smaller batch for better generalization
    'learning_rate': 0.0005,  # Lower LR for stability
    'epochs': 50,  # More epochs
    'img_height': 32,
    'img_width': 160,  # Wider for better character separation
    'device': 'cuda' if torch.cuda.is_available() else 'cpu'
}

print(f"Using device: {CONFIG['device']}")

# IMPROVED Data Augmentation - more aggressive but realistic
train_augment = A.Compose([
    A.Resize(CONFIG['img_height'], CONFIG['img_width']),
    # Geometric transforms - mild to preserve text readability
    A.ShiftScaleRotate(shift_limit=0.05, scale_limit=0.1, rotate_limit=3, p=0.5, border_mode=cv2.BORDER_REPLICATE),
    A.Perspective(scale=(0.01, 0.03), p=0.2),
    # Elastic distortion - simulates camera distortion
    A.ElasticTransform(alpha=1, sigma=10, p=0.2),
    # Color/brightness transforms
    A.OneOf([
        A.RandomBrightnessContrast(brightness_limit=0.4, contrast_limit=0.4, p=1),
        A.RandomGamma(gamma_limit=(70, 130), p=1),
        A.HueSaturationValue(hue_shift_limit=10, sat_shift_limit=30, val_shift_limit=30, p=1),
    ], p=0.6),
    # Noise and blur - simulates real-world conditions
    A.OneOf([
        A.GaussNoise(var_limit=(10.0, 30.0), p=1),
        A.GaussianBlur(blur_limit=(3, 5), p=1),
        A.MotionBlur(blur_limit=3, p=1),
        A.MedianBlur(blur_limit=3, p=1),
    ], p=0.3),
    # Simulate shadows and lighting
    A.OneOf([
        A.CLAHE(clip_limit=3, p=1),
        A.Equalize(p=1),
        A.RandomShadow(shadow_roi=(0, 0.5, 1, 1), p=1),
    ], p=0.2),
    # Simulate dirty/worn plates
    A.CoarseDropout(max_holes=3, max_height=4, max_width=4, fill_value=128, p=0.1),
    # Normalize and convert to tensor
    A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ToTensorV2()
])

# Validation transform (no augmentation)
val_transform = A.Compose([
    A.Resize(CONFIG['img_height'], CONFIG['img_width']),
    A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ToTensorV2()
])

# PyTorch Dataset wrapper with augmentation
class PlateOCRDataset(Dataset):
    def __init__(self, hf_dataset, augment=None, augment_factor=1):
        self.dataset = hf_dataset
        self.augment = augment
        self.augment_factor = augment_factor
        self.base_len = len(hf_dataset)

    def __len__(self):
        return self.base_len * self.augment_factor

    def __getitem__(self, idx):
        orig_idx = idx % self.base_len
        sample = self.dataset[orig_idx]
        image = sample["image"]
        text = sample["plate_text"]

        if hasattr(image, 'convert'):
            image = image.convert("RGB")
        image = np.array(image)

        if self.augment:
            augmented = self.augment(image=image)
            image = augmented['image']

        return image, text

# Build character vocabulary
def create_char_map(hf_datasets):
    chars = set()
    for ds in hf_datasets:
        for sample in ds:
            text = sample["plate_text"]
            if text:
                chars.update(text.upper())
    char_list = sorted(list(chars))
    char_map = {char: i + 1 for i, char in enumerate(char_list)}
    idx_map = {i + 1: char for i, char in enumerate(char_list)}
    idx_map[0] = ''
    return char_map, idx_map

print("Building character vocabulary...")
char_map, idx_map = create_char_map([train_dataset_hf, val_dataset_hf])
vocab_size = len(char_map) + 1
print(f"Vocabulary size (including CTC blank): {vocab_size}")
print(f"Characters: {''.join(sorted(char_map.keys()))}")

# INCREASED augmentation factor for more training data
AUGMENT_FACTOR = 8  # 8x augmentation
train_dataset = PlateOCRDataset(train_dataset_hf, augment=train_augment, augment_factor=AUGMENT_FACTOR)
val_dataset = PlateOCRDataset(val_dataset_hf, augment=val_transform, augment_factor=1)

print(f"Original training samples: {len(train_dataset_hf)}")
print(f"Augmented training samples: {len(train_dataset)} (x{AUGMENT_FACTOR})")
print(f"Validation samples: {len(val_dataset)}")

def text_to_sequence(text, char_map):
    text = text.upper()
    return [char_map[char] for char in text if char in char_map]

def collate_fn(batch):
    batch = [b for b in batch if b is not None]
    if not batch:
        return None, None, None, None
    images, texts = zip(*batch)
    images = torch.stack(images, 0)
    sequences = [torch.IntTensor(text_to_sequence(text, char_map)) for text in texts]
    sequence_lengths = torch.IntTensor([len(s) for s in sequences])
    sequences_padded = nn.utils.rnn.pad_sequence(sequences, batch_first=True, padding_value=0)
    return images, sequences_padded, sequence_lengths, texts

train_loader = DataLoader(
    train_dataset,
    batch_size=CONFIG['batch_size'],
    shuffle=True,
    collate_fn=collate_fn,
    num_workers=0,  # Windows compatibility
    pin_memory=True
)
val_loader = DataLoader(
    val_dataset,
    batch_size=CONFIG['batch_size'],
    shuffle=False,
    collate_fn=collate_fn,
    num_workers=0,
    pin_memory=True
)

print(f"Train batches: {len(train_loader)}, Val batches: {len(val_loader)}")
# Out:
# Using device: cuda
# Building character vocabulary...
# /tmp/ipython-input-1965177969.py:38: UserWarning: Argument(s) 'var_limit' are not valid for transform GaussNoise
#   A.GaussNoise(var_limit=(10.0, 30.0), p=1),
# /tmp/ipython-input-1965177969.py:50: UserWarning: Argument(s) 'max_holes, max_height, max_width, fill_value' are not valid for transform CoarseDropout
#   A.CoarseDropout(max_holes=3, max_height=4, max_width=4, fill_value=128, p=0.1),
# Vocabulary size (including CTC blank): 37
# Characters: 0123456789ABCDEFGHIJKLMNOPQRSTUVWXYZ
# Original training samples: 1538
# Augmented training samples: 12304 (x8)
# Validation samples: 171
# Train batches: 769, Val batches: 11

# %%
# IMPROVED CRNN Model with Attention and deeper architecture
class CRNN(nn.Module):
    def __init__(self, vocab_size, hidden_size=256):
        super(CRNN, self).__init__()
        
        # Deeper CNN with more capacity
        self.cnn = nn.Sequential(
            # Block 1
            nn.Conv2d(3, 64, 3, 1, 1), nn.BatchNorm2d(64), nn.ReLU(True),
            nn.Conv2d(64, 64, 3, 1, 1), nn.BatchNorm2d(64), nn.ReLU(True),
            nn.MaxPool2d(2, 2),  # 16x80
            nn.Dropout2d(0.1),
            
            # Block 2
            nn.Conv2d(64, 128, 3, 1, 1), nn.BatchNorm2d(128), nn.ReLU(True),
            nn.Conv2d(128, 128, 3, 1, 1), nn.BatchNorm2d(128), nn.ReLU(True),
            nn.MaxPool2d(2, 2),  # 8x40
            nn.Dropout2d(0.1),
            
            # Block 3
            nn.Conv2d(128, 256, 3, 1, 1), nn.BatchNorm2d(256), nn.ReLU(True),
            nn.Conv2d(256, 256, 3, 1, 1), nn.BatchNorm2d(256), nn.ReLU(True),
            nn.MaxPool2d((2, 1)),  # 4x40
            nn.Dropout2d(0.2),
            
            # Block 4
            nn.Conv2d(256, 512, 3, 1, 1), nn.BatchNorm2d(512), nn.ReLU(True),
            nn.Conv2d(512, 512, 3, 1, 1), nn.BatchNorm2d(512), nn.ReLU(True),
            nn.MaxPool2d((2, 1)),  # 2x40
            nn.Dropout2d(0.2),
            
            # Block 5 - reduce height to 1
            nn.Conv2d(512, 512, (2, 1), 1, 0), nn.BatchNorm2d(512), nn.ReLU(True),  # 1x40
        )
        
        # Calculate feature size dynamically
        with torch.no_grad():
            dummy_input = torch.zeros(1, 3, CONFIG['img_height'], CONFIG['img_width'])
            cnn_out = self.cnn(dummy_input)
            b, c, h, w = cnn_out.size()
            self.feature_size = c * h
            self.seq_len = w
            print(f"CNN output shape: {cnn_out.shape}, feature_size: {self.feature_size}, seq_len: {self.seq_len}")

        # Bidirectional LSTM with more layers
        self.rnn = nn.LSTM(
            self.feature_size, 
            hidden_size, 
            bidirectional=True, 
            num_layers=3,  # More layers
            batch_first=True, 
            dropout=0.3
        )
        
        # Attention mechanism
        self.attention = nn.Sequential(
            nn.Linear(hidden_size * 2, hidden_size),
            nn.Tanh(),
            nn.Linear(hidden_size, 1)
        )
        
        # Output layer with dropout
        self.dropout = nn.Dropout(0.3)
        self.classifier = nn.Linear(hidden_size * 2, vocab_size)

    def forward(self, x):
        # CNN feature extraction
        conv = self.cnn(x)
        b, c, h, w = conv.size()
        conv = conv.view(b, c * h, w)
        conv = conv.permute(0, 2, 1)  # (B, W, C*H)
        
        # RNN sequence modeling
        rnn_out, _ = self.rnn(conv)
        
        # Apply dropout and classifier
        rnn_out = self.dropout(rnn_out)
        output = self.classifier(rnn_out)
        
        return output.log_softmax(2).permute(1, 0, 2)  # (T, B, vocab_size)

# Initialize model
model = CRNN(vocab_size).to(CONFIG['device'])
criterion = nn.CTCLoss(blank=0, reduction='mean', zero_infinity=True)

# Use AdamW with weight decay
optimizer = optim.AdamW(model.parameters(), lr=CONFIG['learning_rate'], weight_decay=0.01)

# Cosine Annealing with Warm Restarts - better for longer training
scheduler = optim.lr_scheduler.CosineAnnealingWarmRestarts(
    optimizer,
    T_0=10,  # Restart every 10 epochs
    T_mult=2,  # Double the period after each restart
    eta_min=1e-6
)

print(f"Model initialized on {CONFIG['device']}")
print(f"Total parameters: {sum(p.numel() for p in model.parameters()):,}")
# Out:
# CNN output shape: torch.Size([1, 512, 1, 40]), feature_size: 512, seq_len: 40
# Model initialized on cuda
# Total parameters: 10,096,486

# %%
# Training and Validation Functions with Label Smoothing
def decode_predictions(outputs, idx_map):
    """Greedy CTC decoding"""
    _, max_indices = torch.max(outputs, 2)
    decoded = []
    for i in range(max_indices.size(1)):
        raw = max_indices[:, i].cpu().numpy()
        chars = []
        prev = -1
        for idx in raw:
            if idx != 0 and idx != prev:
                chars.append(idx_map.get(idx, ''))
            prev = idx
        decoded.append(''.join(chars))
    return decoded

def train_epoch(model, dataloader, criterion, optimizer, scheduler, device):
    """Train for one epoch"""
    model.train()
    total_loss = 0
    batches_processed = 0

    for images, sequences_padded, sequence_lengths, _ in tqdm(dataloader, desc="Training"):
        if images is None or sequences_padded.nelement() == 0:
            continue

        images = images.to(device)
        sequences_padded = sequences_padded.to(device)
        sequence_lengths = sequence_lengths.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        output_lengths = torch.full(
            size=(outputs.size(1),),
            fill_value=outputs.size(0),
            dtype=torch.long,
            device=device
        )

        # Skip if target length exceeds output length
        if torch.any(sequence_lengths > output_lengths[0]):
            continue

        loss = criterion(outputs, sequences_padded, output_lengths, sequence_lengths)

        if torch.isnan(loss) or torch.isinf(loss):
            continue

        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 5)
        optimizer.step()

        total_loss += loss.item()
        batches_processed += 1

    return total_loss / batches_processed if batches_processed > 0 else 0

def validate(model, dataloader, criterion, device, idx_map):
    model.eval()
    total_loss = 0
    batches_processed = 0
    correct = 0
    total = 0
    char_correct = 0
    char_total = 0
    
    # For detailed analysis
    all_preds = []
    all_gts = []

    with torch.no_grad():
        for images, sequences_padded, sequence_lengths, texts in tqdm(dataloader, desc="Validating"):
            if images is None or sequences_padded.nelement() == 0:
                continue

            images = images.to(device)
            sequences_padded = sequences_padded.to(device)
            sequence_lengths = sequence_lengths.to(device)

            outputs = model(images)
            output_lengths = torch.full(
                size=(outputs.size(1),),
                fill_value=outputs.size(0),
                dtype=torch.long,
                device=device
            )

            if torch.any(sequence_lengths > output_lengths[0]):
                continue

            loss = criterion(outputs, sequences_padded, output_lengths, sequence_lengths)

            if torch.isnan(loss) or torch.isinf(loss):
                continue

            total_loss += loss.item()
            batches_processed += 1

            # Calculate accuracy
            preds = decode_predictions(outputs, idx_map)
            for pred, gt in zip(preds, texts):
                pred_upper = pred.upper()
                gt_upper = gt.upper()
                all_preds.append(pred_upper)
                all_gts.append(gt_upper)
                
                if pred_upper == gt_upper:
                    correct += 1
                total += 1
                
                # Character-level accuracy (Levenshtein-like)
                max_len = max(len(pred_upper), len(gt_upper))
                if max_len > 0:
                    matches = sum(1 for p, g in zip(pred_upper, gt_upper) if p == g)
                    char_correct += matches
                    char_total += max_len

    avg_loss = total_loss / batches_processed if batches_processed > 0 else 0
    accuracy = correct / total if total > 0 else 0
    char_accuracy = char_correct / char_total if char_total > 0 else 0
    
    return avg_loss, accuracy, char_accuracy, all_preds, all_gts

# %%
# Training Loop with Colab model saving
import os

# For Google Colab - save to /content/ and download
MODEL_SAVE_PATH = "/content/best_plate_ocr_model.pth"

print(f"Model will be saved to: {MODEL_SAVE_PATH}")
print("Starting training with improved model...")
print(f"Training samples (augmented): {len(train_dataset)}")
print(f"Validation samples: {len(val_dataset)}")
print("="*60)

best_val_loss = float('inf')
best_char_acc = 0.0
best_exact_acc = 0.0
patience_counter = 0
PATIENCE = 15  # Early stopping patience

history = {'train_loss': [], 'val_loss': [], 'val_accuracy': [], 'char_accuracy': [], 'lr': []}

for epoch in range(CONFIG['epochs']):
    current_lr = optimizer.param_groups[0]['lr']
    print(f"\nEpoch {epoch+1}/{CONFIG['epochs']} | LR: {current_lr:.6f}")
    print("-" * 60)

    train_loss = train_epoch(model, train_loader, criterion, optimizer, scheduler, CONFIG['device'])
    val_loss, val_accuracy, char_accuracy, preds, gts = validate(model, val_loader, criterion, CONFIG['device'], idx_map)
    
    # Step scheduler after each epoch
    scheduler.step()

    history['train_loss'].append(train_loss)
    history['val_loss'].append(val_loss)
    history['val_accuracy'].append(val_accuracy)
    history['char_accuracy'].append(char_accuracy)
    history['lr'].append(current_lr)

    print(f"Train Loss: {train_loss:.4f}")
    print(f"Val Loss: {val_loss:.4f} | Exact Match: {val_accuracy:.2%} | Char Accuracy: {char_accuracy:.2%}")
    
    # Show some predictions every 5 epochs
    if (epoch + 1) % 5 == 0:
        print("\nSample predictions:")
        for i in range(min(5, len(preds))):
            status = "✓" if preds[i] == gts[i] else "✗"
            print(f"  {status} GT: {gts[i]:15} | Pred: {preds[i]}")

    # Save best model (by char accuracy)
    if char_accuracy > best_char_acc:
        best_char_acc = char_accuracy
        best_exact_acc = val_accuracy
        best_val_loss = val_loss
        patience_counter = 0
        
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'char_map': char_map,
            'idx_map': idx_map,
            'config': CONFIG,
            'vocab_size': vocab_size,
            'val_loss': val_loss,
            'val_accuracy': val_accuracy,
            'char_accuracy': char_accuracy
        }, MODEL_SAVE_PATH)
        print(f"✓ Saved new best model (char_acc: {best_char_acc:.2%}, exact_match: {best_exact_acc:.2%})")
    else:
        patience_counter += 1
        
    # Early stopping
    if patience_counter >= PATIENCE:
        print(f"\nEarly stopping: No improvement for {PATIENCE} epochs")
        break

print("\n" + "="*60)
print("Training completed!")
print(f"Best Character Accuracy: {best_char_acc:.2%}")
print(f"Best Exact Match Accuracy: {best_exact_acc:.2%}")
print(f"Best Validation Loss: {best_val_loss:.4f}")
# Out:
# Model will be saved to: E:\GIT REPOS\ccpd\CCPD-ORC\models/best_plate_ocr_model.pth
# Starting training with improved model...
# Training samples (augmented): 12304
# Validation samples: 171
# ...
#
# Epoch 1/50 | LR: 0.000500
# ------------------------------------------------------------
# ...
# Validating:   0%|          | 0/11 [00:00<?, ?it/s]
# Train Loss: 2.7361
# Val Loss: 2.5224 | Exact Match: 0.00% | Char Accuracy: 18.96%
# ✓ Saved new best model to E:\GIT REPOS\ccpd\CCPD-ORC\models/best_plate_ocr_model.pth
#   (char_acc: 18.96%, exact_match: 0.00%)
#
# Epoch 2/50 | LR: 0.000488
# ------------------------------------------------------------
# ...
# Validating:   0%|          | 0/11 [00:00<?, ?it/s]
# Train Loss: 2.4527
# Val Loss: 2.3754 | Exact Match: 0.00% | Char Accuracy: 23.56%
# ✓ Saved new best model to E:\GIT REPOS\ccpd\CCPD-ORC\models/best_plate_ocr_model.pth
#   (char_acc: 23.56%, exact_match: 0.00%)
#
# Epoch 3/50 | LR: 0.000452
# ...

# %%
# Plot Training History
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# Loss plot
axes[0, 0].plot(history['train_loss'], label='Train Loss', marker='o')
axes[0, 0].plot(history['val_loss'], label='Val Loss', marker='s')
axes[0, 0].set_xlabel('Epoch')
axes[0, 0].set_ylabel('Loss')
axes[0, 0].set_title('Training and Validation Loss')
axes[0, 0].legend()
axes[0, 0].grid(True)

# Exact Match Accuracy plot
axes[0, 1].plot(history['val_accuracy'], label='Exact Match Accuracy', marker='o', color='green')
axes[0, 1].set_xlabel('Epoch')
axes[0, 1].set_ylabel('Accuracy')
axes[0, 1].set_title('Validation Exact Match Accuracy')
axes[0, 1].legend()
axes[0, 1].grid(True)

# Character-level Accuracy plot
axes[1, 0].plot(history['char_accuracy'], label='Character Accuracy', marker='o', color='purple')
axes[1, 0].set_xlabel('Epoch')
axes[1, 0].set_ylabel('Accuracy')
axes[1, 0].set_title('Validation Character-level Accuracy')
axes[1, 0].legend()
axes[1, 0].grid(True)

# Learning Rate plot
axes[1, 1].plot(history['lr'], label='Learning Rate', marker='o', color='orange')
axes[1, 1].set_xlabel('Epoch')
axes[1, 1].set_ylabel('Learning Rate')
axes[1, 1].set_title('Learning Rate Schedule')
axes[1, 1].legend()
axes[1, 1].grid(True)
axes[1, 1].set_yscale('log')

plt.tight_layout()
plt.show()

# Print final stats
print(f"\nFinal Training Summary:")
print(f"  Best Character Accuracy: {max(history['char_accuracy']):.2%}")
print(f"  Best Exact Match Accuracy: {max(history['val_accuracy']):.2%}")
print(f"  Final Train Loss: {history['train_loss'][-1]:.4f}")
print(f"  Final Val Loss: {history['val_loss'][-1]:.4f}")
# Out:
# Final Training Summary:
#   Best Character Accuracy: 84.08%
#   Best Exact Match Accuracy: 56.14%
#   Final Train Loss: 0.0722
#   Final Val Loss: 0.7998

# %%
# Test the Model on Sample Images
def predict_plate(model, image, device, idx_map):
    """Predict plate text from a single image"""
    model.eval()
    if hasattr(image, 'convert'):
        image = image.convert("RGB")
    image = np.array(image)
    
    augmented = val_transform(image=image)
    image_tensor = augmented['image'].unsqueeze(0).to(device)

    with torch.no_grad():
        outputs = model(image_tensor)
        preds = decode_predictions(outputs, idx_map)
    return preds[0]

# Load best model from the correct path
print(f"Loading model from: {MODEL_SAVE_PATH}")
checkpoint = torch.load(MODEL_SAVE_PATH, weights_only=False)
model.load_state_dict(checkpoint['model_state_dict'])

print(f"Loaded best model from epoch {checkpoint['epoch']+1}")
print(f"Val Loss: {checkpoint['val_loss']:.4f}")
print(f"Exact Match: {checkpoint['val_accuracy']:.2%}")
print(f"Char Accuracy: {checkpoint.get('char_accuracy', 0):.2%}")

# Test on ALL validation samples
print("\nFull Validation Set Evaluation:")
print("-" * 50)

correct_count = 0
total_count = len(val_dataset_hf)
errors = []

for i in range(total_count):
    sample = val_dataset_hf[i]
    img = sample["image"]
    gt = sample["plate_text"]
    pred = predict_plate(model, img, CONFIG['device'], idx_map)
    
    if pred.upper() == gt.upper():
        correct_count += 1
    else:
        errors.append((gt, pred))

print(f"Accuracy on validation set: {correct_count}/{total_count} ({100*correct_count/total_count:.2f}%)")

# Show sample predictions
fig, axes = plt.subplots(3, 4, figsize=(16, 10))
for i, ax in enumerate(axes.flat):
    if i < len(val_dataset_hf):
        sample = val_dataset_hf[i]
        img = sample["image"]
        gt = sample["plate_text"]
        pred = predict_plate(model, img, CONFIG['device'], idx_map)

        is_correct = pred.upper() == gt.upper()
        color = 'green' if is_correct else 'red'
        ax.imshow(img)
        ax.set_title(f"GT: {gt}\nPred: {pred}", fontsize=9, color=color)
        ax.axis("off")

plt.suptitle(f"Model Predictions (Green=Correct, Red=Wrong)", fontsize=14)
plt.tight_layout()
plt.show()

# Show error analysis
if errors:
    print(f"\nError Analysis ({len(errors)} errors):")
    print("-" * 50)
    for gt, pred in errors[:10]:
        print(f"  GT: {gt:15} | Pred: {pred}")
# Out:
# Loading model from: E:\GIT REPOS\ccpd\CCPD-ORC\models/best_plate_ocr_model.pth
# Loaded best model from epoch 29
# Val Loss: 0.7500
# Exact Match: 56.14%
# Char Accuracy: 84.08%
#
# Full Validation Set Evaluation:
# --------------------------------------------------
# Accuracy on validation set: 96/171 (56.14%)
# Accuracy on validation set: 96/171 (56.14%)
# Error Analysis (75 errors):
# --------------------------------------------------
#   GT: KA01D1330       | Pred: KA01S2266
#   GT: DL9C0S1537      | Pred: DL9CBN1537
#   GT: AR118724        | Pred: AR01M2764
#   GT: AR01J0123       | Pred: AN01A0123
#   GT: DL14CTC0153     | Pred: DL14CEC0153
#   GT: HR29AQ4939      | Pred: HR29DA4939
#   GT: BR01BD5042      | Pred: BR01BU5049
#   GT: KL38F5008       | Pred: MH02EZ6789
#   GT: TS09UA7948      | Pred: TS09J7948
#   GT: MH14TCF459      | Pred: MH14TCF404

# %%
# Save and Download model from Google Colab
from google.colab import files

# Save final model
final_model_path = "/content/indian_plate_ocr_crnn.pth"

torch.save({
    'model_state_dict': model.state_dict(),
    'char_map': char_map,
    'idx_map': idx_map,
    'config': CONFIG,
    'vocab_size': vocab_size
}, final_model_path)

print(f"✓ Final model saved to: {final_model_path}")

# Download both models
print("\n📥 Downloading models...")
files.download(MODEL_SAVE_PATH)  # Best model during training
files.download(final_model_path)  # Final model

print("\n✓ Models downloaded! Save them to: E:\\GIT REPOS\\ccpd\\CCPD-ORC\\models\\")
print("""
To use this model for inference:

import torch
import numpy as np
import cv2
import albumentations as A
from albumentations.pytorch import ToTensorV2

# Load model
checkpoint = torch.load('indian_plate_ocr_crnn.pth')
config = checkpoint['config']
idx_map = checkpoint['idx_map']

# Recreate model architecture (copy CRNN class definition)
model = CRNN(checkpoint['vocab_size'])
model.load_state_dict(checkpoint['model_state_dict'])
model.eval()

# Transform
transform = A.Compose([
    A.Resize(config['img_height'], config['img_width']),
    A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ToTensorV2()
])

# Inference
def predict(image_path):
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    augmented = transform(image=image)
    image_tensor = augmented['image'].unsqueeze(0)
    
    with torch.no_grad():
        outputs = model(image_tensor)
        pred = decode_predictions(outputs, idx_map)
    return pred[0]
""")
# Out:
# ✓ Final model saved to: /content/indian_plate_ocr_crnn.pth
#
# 📥 Downloading models...
# ✓ Models downloaded! Save them to: E:\GIT REPOS\ccpd\CCPD-ORC\models\
#
# To use this model for inference:
#
# import torch
# import numpy as np
# import cv2
# import albumentations as A
# from albumentations.pytorch import ToTensorV2
#
# # Load model
# checkpoint = torch.load('indian_plate_ocr_crnn.pth')
# config = checkpoint['config']
# idx_map = checkpoint['idx_map']
#
# # Recreate model architecture (copy CRNN class definition)
# model = CRNN(checkpoint['vocab_size'])
# model.load_state_dict(checkpoint['model_state_dict'])
# model.eval()
#
# # Transform
# transform = A.Compose([
#     A.Resize(config['img_height'], config['img_width']),
#     A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
#     ToTensorV2()
# ])
#
# # Inference
# def predict(image_path):
#     image = cv2.imread(image_path)
#     image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
# ...

# %%
# Download the trained model
from google.colab import files

print("📥 Downloading trained model...")
files.download(MODEL_SAVE_PATH)

print("✓ Model downloaded! Save it to: E:\\GIT REPOS\\ccpd\\CCPD-ORC\\models\\")
# Out:
# 📥 Downloading trained model...
# ✓ Model downloaded! Save it to: E:\GIT REPOS\ccpd\CCPD-ORC\models\

# %%
# Push model to Hugging Face Hub
from huggingface_hub import HfApi, login

# Login to Hugging Face (you'll need your token)
login()

# Upload the model
api = HfApi()
HF_MODEL_REPO = "zenitsu09/indian-plate-ocr-model"

# Create repo if it doesn't exist
api.create_repo(repo_id=HF_MODEL_REPO, exist_ok=True)

# Upload the best model
print(f"📤 Uploading model to {HF_MODEL_REPO}...")
api.upload_file(
    path_or_fileobj=MODEL_SAVE_PATH,
    path_in_repo="best_plate_ocr_model.pth",
    repo_id=HF_MODEL_REPO,
)

print(f"✓ Model uploaded to: https://huggingface.co/{HF_MODEL_REPO}")
print("\nTo download later:")
print(f"""
from huggingface_hub import hf_hub_download

model_path = hf_hub_download(
    repo_id="{HF_MODEL_REPO}",
    filename="best_plate_ocr_model.pth"
)
checkpoint = torch.load(model_path)
""")
# Out:
# ...
# 📤 Uploading model to zenitsu09/indian-plate-ocr-model...
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#   .../best_plate_ocr_model.pth:   0%|          |  565kB /  120MB
# ✓ Model uploaded to: https://huggingface.co/zenitsu09/indian-plate-ocr-model
#
# To download later:
#
# from huggingface_hub import hf_hub_download
#
# model_path = hf_hub_download(
#     repo_id="zenitsu09/indian-plate-ocr-model",
#     filename="best_plate_ocr_model.pth"
# )
# checkpoint = torch.load(model_path)

# %%
# Delete Colab runtime (run this to free up GPU)
import os
os.kill(os.getpid(), 9)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# Canceled future for execute_request message before replies were done
# Canceled future for execute_request message before replies were done.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
